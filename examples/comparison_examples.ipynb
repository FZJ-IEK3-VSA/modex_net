# %%
import pandas as pd
import numpy as np
from modex_net import indicators

import logging
logging.basicConfig(level=logging.INFO)

from matplotlib import pyplot as plt

import matplotlib
# %matplotlib inline

figsize = (16, 9)
fontsize = 32

# %% [markdown]
# # Retrieve data

# %%
token = "3a67ee70cc209193aff8ade2c5a0b6d01b3265ce"
comp2016 = indicators.Calculator(2016, data_source="oep", oep_token=token)
# Out:
# INFO:modex_net.indicators:All methods assume hourly profiles.

# %%
dfs = comp2016.energy_mix
# Out:
# WARNING:modex_net.indicators:Missing carrier for energy_mix in model europower. Filling with zeros.
# WARNING:modex_net.indicators:Missing columns for energy_mix in model europower. Filling with zeros.
# ERROR:modex_net.indicators:Table for perseus could not be retrieved. Returning zeros.
# WARNING:modex_net.indicators:Missing carrier for energy_mix in model mars. Filling with zeros.
# WARNING:modex_net.indicators:Missing columns for energy_mix in model mars. Filling with zeros.
# ERROR:modex_net.indicators:Table for powerflex could not be retrieved. Returning zeros.
# WARNING:modex_net.indicators:Missing carrier for energy_mix in model ego. Filling with zeros.
# WARNING:modex_net.indicators:Missing columns for energy_mix in model ego. Filling with zeros.
# WARNING:modex_net.indicators:Missing carrier for energy_mix in model miles. Filling with zeros.
# WARNING:modex_net.indicators:Missing columns for energy_mix in model miles. Filling with zeros.
# WARNING:modex_net.indicators:Missing carrier for energy_mix in model isaar. Filling with zeros.
# ERROR:modex_net.indicators:Table for elmod could not be retrieved. Returning zeros.
# 100% |########################################################################|

# %%
comp2016.warning_flags
# Out:
#           vres_curtailments emissions load_curtailments storage_p storage_soc  \
# europower          Unknown.  Unknown.          Unknown.  Unknown.    Unknown.
# perseus            Unknown.  Unknown.          Unknown.  Unknown.    Unknown.
# mars               Unknown.  Unknown.          Unknown.  Unknown.    Unknown.
# powerflex          Unknown.  Unknown.          Unknown.  Unknown.    Unknown.
# ego                Unknown.  Unknown.          Unknown.  Unknown.    Unknown.
# miles              Unknown.  Unknown.          Unknown.  Unknown.    Unknown.
# isaar              Unknown.  Unknown.          Unknown.  Unknown.    Unknown.
# elmod              Unknown.  Unknown.          Unknown.  Unknown.    Unknown.
#
#           import_export electricity_prices            energy_mix
# europower      Unknown.           Unknown.        Partly broken.
# perseus        Unknown.           Unknown.  Missing table. Zeros
# mars           Unknown.           Unknown.        Partly broken.
# powerflex      Unknown.           Unknown.  Missing table. Zeros
# ego            Unknown.           Unknown.        Partly broken.
# miles          Unknown.           Unknown.        Partly broken.
# isaar          Unknown.           Unknown.        Partly broken.
# elmod          Unknown.           Unknown.  Missing table. Zeros

# %% [markdown]
# # calculate an indicator

# %%
indicators.model_names
# Out:
# ['europower', 'perseus', 'mars', 'powerflex', 'ego', 'miles', 'isaar', 'elmod']

# %%
indicators.quantities
# Out:
# ['vres_curtailments',
#  'emissions',
#  'load_curtailments',
#  'storage_p',
#  'storage_soc',
#  'import_export',
#  'electricity_prices',
#  'energy_mix']

# %%
indicators.metrics_dict.keys()
# Out:
# dict_keys(['wasserstein', 'wasserstein_norm', 'bhattacharyya', 'bhattacharyya_norm', 'max_diff', 'max_diff_norm', 'mape', 'mape_norm', 'euclidean', 'euclidean_norm', 'frechet', 'frechet_norm', 'dtw', 'dtw_norm', 'correlation'])

# %%
indicators.operators_dict.keys()
# Out:
# dict_keys(['sum', 'mean', 'std', 'normalized_std', 'percentile', 'percentile_converter'])

# %%
comp2016.reduction('energy_mix', 'sum')
# Out:
# INFO:modex_net.indicators:Retrieving energy_mix
# 100% |########################################################################|
#      europower  perseus     mars  powerflex         ego    miles   isaar  \
# AT   52.121655      0.0   59.663        0.0   66.385548   65.252   71.68
# BE   60.362823      0.0   71.418        0.0   74.775153   73.669   65.48
# CH   54.895719      0.0   60.808        0.0   60.577627   70.304   68.89
# CZ   97.876834      0.0   79.348        0.0   77.576433   97.376   90.44
# DE  515.560019      0.0  592.285        0.0  544.960497  610.488  592.47
# DK   32.553536      0.0   26.857        0.0   31.634592   27.556   49.18
# FR  611.176717      0.0  549.460        0.0  561.647452  546.749  530.71
# LU    3.451748      0.0    2.753        0.0    1.829502    0.958    1.75
# NL   72.328011      0.0  111.526        0.0   81.741474  100.778   87.00
# NO  127.734112      0.0  144.761        0.0  160.701639  152.529  145.90
# PL  137.837017      0.0  144.079        0.0  154.713346  144.082  158.63
# SE  190.130818      0.0  153.876        0.0  147.490076  159.325  175.83
# BG    0.000000      0.0    0.000        0.0    0.000000    0.000   38.38
# EE    0.000000      0.0    0.000        0.0    0.000000    0.000    2.93
# ES    0.000000      0.0    0.000        0.0    0.000000    0.000  234.88
# FI    0.000000      0.0    0.000        0.0    0.000000    0.000   78.62
# GR    0.000000      0.0    0.000        0.0    0.000000    0.000   53.85
# HU    0.000000      0.0    0.000        0.0    0.000000    0.000   29.31
# IE    0.000000      0.0    0.000        0.0    0.000000    0.000   25.29
# IT    0.000000      0.0    0.000        0.0    0.000000    0.000  257.78
# LT    0.000000      0.0    0.000        0.0    0.000000    0.000   20.44
# LV    0.000000      0.0    0.000        0.0    0.000000    0.000    7.08
# PT    0.000000      0.0    0.000        0.0    0.000000    0.000   52.56
# RO    0.000000      0.0    0.000        0.0    0.000000    0.000   53.76
# SK    0.000000      0.0    0.000        0.0    0.000000    0.000   31.72
# UK    0.000000      0.0    0.000        0.0    0.000000    0.000  332.05
#
#     elmod
# AT    0.0
# BE    0.0
# CH    0.0
# CZ    0.0
# DE    0.0
# DK    0.0
# FR    0.0
# LU    0.0
# NL    0.0
# NO    0.0
# PL    0.0
# SE    0.0
# BG    0.0
# EE    0.0
# ES    0.0
# FI    0.0
# GR    0.0
# HU    0.0
# IE    0.0
# IT    0.0
# LT    0.0
# LV    0.0
# PT    0.0
# RO    0.0
# SK    0.0
# UK    0.0

# %%
comp2016.pair_distance_single('energy_mix', 'max_diff', 'europower')
# Out:
# INFO:modex_net.indicators:Retrieving energy_mix
# 100% |########################################################################|
#     europower     perseus        mars   powerflex        ego       miles  \
# AT        0.0   24.430444   10.730193   24.430444   6.879840   20.449556
# BE        0.0   46.116132   18.583044   46.116132  10.558482   16.610044
# CH        0.0   25.769094   13.403063   25.769094  16.159185   23.677898
# CZ        0.0   56.076114   22.651114   56.076114  21.602935    1.789140
# DE        0.0  159.564072   62.240128  159.564072  34.650296   47.126128
# DK        0.0   10.868942    4.699970   10.868942   3.205072    5.186561
# FR        0.0  469.257627   26.457474  469.257627  39.467750   49.282627
# LU        0.0    1.802001    1.502188    1.802001   1.494332    1.502188
# NL        0.0   33.145919   48.805361   33.145919  20.988994   35.282361
# NO        0.0  120.917114  140.998992  120.917114  35.546122  148.387000
# PL        0.0   65.234553   19.089098   65.234553  22.136110    6.248902
# SE        0.0   73.575069   63.769470   73.575069  36.281462   60.087881
# BG        0.0    0.000000    0.000000    0.000000   0.000000    0.000000
# EE        0.0    0.000000    0.000000    0.000000   0.000000    0.000000
# ES        0.0    0.000000    0.000000    0.000000   0.000000    0.000000
# FI        0.0    0.000000    0.000000    0.000000   0.000000    0.000000
# GR        0.0    0.000000    0.000000    0.000000   0.000000    0.000000
# HU        0.0    0.000000    0.000000    0.000000   0.000000    0.000000
# IE        0.0    0.000000    0.000000    0.000000   0.000000    0.000000
# IT        0.0    0.000000    0.000000    0.000000   0.000000    0.000000
# LT        0.0    0.000000    0.000000    0.000000   0.000000    0.000000
# LV        0.0    0.000000    0.000000    0.000000   0.000000    0.000000
# PT        0.0    0.000000    0.000000    0.000000   0.000000    0.000000
# RO        0.0    0.000000    0.000000    0.000000   0.000000    0.000000
# SK        0.0    0.000000    0.000000    0.000000   0.000000    0.000000
# UK        0.0    0.000000    0.000000    0.000000   0.000000    0.000000
#
#          isaar       elmod
# AT    8.105089   24.430444
# BE   11.178044   46.116132
# CH   11.738377   25.769094
# CZ   11.966114   56.076114
# DE   58.980924  159.564072
# DK    8.070030   10.868942
# FR   73.177627  469.257627
# LU    1.122001    1.802001
# NL   19.520361   33.145919
# NO   21.792886  120.917114
# PL   55.529098   65.234553
# SE    7.257881   73.575069
# BG   16.380000    0.000000
# EE    1.920000    0.000000
# ES   52.810000    0.000000
# FI   35.290000    0.000000
# GR   30.240000    0.000000
# HU   13.980000    0.000000
# IE   10.360000    0.000000
# IT   89.160000    0.000000
# LT   17.700000    0.000000
# LV    2.520000    0.000000
# PT   13.590000    0.000000
# RO   16.020000    0.000000
# SK   15.230000    0.000000
# UK  103.670000    0.000000

# %% [markdown]
# # energy mix

# %%
ax = comp2016.plot_energy_mix(relative=False, aggregate=True, fontsize=24)
# Out:
# INFO:modex_net.indicators:Retrieving energy_mix
# 100% |########################################################################|

# %%
comp2016.plot_energy_mix(relative=True, aggregate=True, fontsize=24)
# Out:
# INFO:modex_net.indicators:Retrieving energy_mix
# 100% |########################################################################|
# WARNING:modex_net.indicators:Removing ylabel for relative values.
# <AxesSubplot:>

# %%
comp2016.plot_heatmap('energy_mix')
# Out:
# INFO:modex_net.indicators:Retrieving energy_mix
# 100% |########################################################################|
# c:\users\k.syranidis\sciebo_c\repos\modex-net\modex_net\modex_net\indicators.py:351: RuntimeWarning: invalid value encountered in double_scalars
#   return (reg_indicator * df1.sum()).sum() / df1.sum().sum()
# c:\users\k.syranidis\sciebo_c\repos\modex-net\modex_net\modex_net\plots.py:259: UserWarning: FixedFormatter should only be used together with FixedLocator
#   cbar.ax.set_yticklabels([str(i)+'%' for i in range(0, 120, 20)], fontsize=fontsize)
# <__array_function__ internals>:5: UserWarning: Warning: converting a masked element to nan.
# C:\Users\k.syranidis\AppData\Local\Continuum\Anaconda3\envs\modex_net_comparison\lib\site-packages\numpy\core\_asarray.py:85: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)
# <AxesSubplot:>

# %% [markdown]
# # electricity prices

# %%
ax = comp2016.plot_dendrogram('electricity_prices', 'mean', fontsize=fontsize, figsize=figsize)
ax.set_title('')
ax.set_ylabel('€/MWh', fontsize=fontsize)
# Out:
# INFO:modex_net.indicators:Retrieving electricity_prices
# 100% |########################################################################|
# Text(71.875, 0.5, '€/MWh')

# %%
comp2016.plot_heatmap('electricity_prices', 'max_diff', 'powerflex')
# Out:
# INFO:modex_net.indicators:Retrieving electricity_prices
# 100% |########################################################################|
# c:\users\k.syranidis\sciebo_c\repos\modex-net\modex_net\modex_net\plots.py:261: UserWarning: FixedFormatter should only be used together with FixedLocator
#   cbar.ax.set_yticklabels([valfmt.replace('x', '').format(i) for i in
# <AxesSubplot:title={'center':'powerflex model'}>

# %%
ax = comp2016.plot_taylor_diagram('electricity_prices', 'DE', 'powerflex')
# Out:
# INFO:modex_net.indicators:Retrieving electricity_prices
# 100% |########################################################################|
# INFO:modex_net.indicators:Retrieving electricity_prices
# 100% |########################################################################|
# c:\users\k.syranidis\sciebo_c\repos\modex-net\modex_net\modex_net\ntaylor\ntaylor.py:192: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([abs(round(i - 1, 2)) for i in ax.get_xticks()], fontsize=fontsize)

# %%
df = comp2016.price_convergence()
# Out:
# INFO:modex_net.indicators:Retrieving electricity_prices
# 100% |########################################################################|

# %%
ax = df['regional convergence'].T.plot(kind='bar', figsize=(14,8), fontsize=24)
ax.set_ylim(0, 100)
ax.set_ylabel('%', fontsize=24)
ax.legend(fontsize=24)
